# %%
# !pip install max --index-url https://dl.modular.com/public/nightly/python/simple/
# Out:
# Looking in indexes: https://dl.modular.com/public/nightly/python/simple/
# Collecting max
#   Downloading https://dl.modular.com/public/nightly/python/max-25.4.0.dev2025060613-py3-none-manylinux_2_34_x86_64.whl (284.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.8/284.8 MB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from max) (8.2.1)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.11/dist-packages (from max) (2.0.2)
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.11/dist-packages (from max) (4.67.1)
# Installing collected packages: max
# Successfully installed max-25.4.0.dev2025060613

# %%
import max.support.notebook

# %%
# !git clone https://github.com/modular/mojo-gpu-puzzles
# Out:
# Cloning into 'mojo-gpu-puzzles'...
# remote: Enumerating objects: 4059, done.
# remote: Counting objects: 100% (166/166), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 4059 (delta 151), reused 127 (delta 127), pack-reused 3893 (from 2)
# Receiving objects: 100% (4059/4059), 94.69 MiB | 13.81 MiB/s, done.
# Resolving deltas: 100% (2489/2489), done.

# %%
# !curl -fsSL https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.7.12 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
mojo_code = """
from memory import UnsafePointer
from gpu import thread_idx, block_dim, block_idx
from gpu.host import DeviceContext
from testing import assert_equal

# ANCHOR: add
alias SIZE = 4
alias BLOCKS_PER_GRID = 1
alias THREADS_PER_BLOCK = SIZE
alias dtype = DType.float32


fn add(
    output: UnsafePointer[Scalar[dtype]],
    a: UnsafePointer[Scalar[dtype]],
    b: UnsafePointer[Scalar[dtype]],
):
    i = thread_idx.x
    # FILL ME IN (roughly 1 line)
    output[i] = a[i] + b[i]

# ANCHOR_END: add


def main():
    with DeviceContext() as ctx:
        out = ctx.enqueue_create_buffer[dtype](SIZE).enqueue_fill(0)
        a = ctx.enqueue_create_buffer[dtype](SIZE).enqueue_fill(0)
        b = ctx.enqueue_create_buffer[dtype](SIZE).enqueue_fill(0)
        expected = ctx.enqueue_create_host_buffer[dtype](SIZE).enqueue_fill(0)
        with a.map_to_host() as a_host, b.map_to_host() as b_host:
            for i in range(SIZE):
                a_host[i] = i
                b_host[i] = i
                expected[i] = a_host[i] + b_host[i]

        ctx.enqueue_function[add](
            out.unsafe_ptr(),
            a.unsafe_ptr(),
            b.unsafe_ptr(),
            grid_dim=BLOCKS_PER_GRID,
            block_dim=THREADS_PER_BLOCK,
        )

        ctx.synchronize()

        with out.map_to_host() as out_host:
            print("out:", out_host)
            print("expected:", expected)
            for i in range(SIZE):
                assert_equal(out_host[i], expected[i])

"""

# %%
def save_code_to_file(text: str, filename: str):
    with open(filename, 'w', encoding='utf-8') as file:
        file.write(text)

# %%
save_code_to_file(mojo_code, "/content/mojo-gpu-puzzles/problems/p02/p02.mojo")

# %%
# !cd /content/mojo-gpu-puzzles && uv run poe p02
# Out:
# Using CPython 3.11.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# ⠙ Preparing packages... (0/7)
# ⠙ Preparing packages... (0/7)
# ⠙ Preparing packages... (0/7)
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)
# pastel               ------------------------------     0 B/5.82 KiB
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)
# pastel               ------------------------------ 5.82 KiB/5.82 KiB
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)
# pastel               ------------------------------ 5.82 KiB/5.82 KiB
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)
# pastel               ------------------------------ 5.82 KiB/5.82 KiB
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)
# pastel               ------------------------------ 5.82 KiB/5.82 KiB
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# ⠙ Preparing packages... (0/7)
# pastel               ------------------------------ 5.82 KiB/5.82 KiB
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# click                ------------------------------ 30.88 KiB/99.82 KiB
# ⠙ Preparing packages... (0/7)
# pastel               ------------------------------ 5.82 KiB/5.82 KiB
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# click                ------------------------------ 30.88 KiB/99.82 KiB
# ⠙ Preparing packages... (0/7)
# pastel               ------------------------------ 5.82 KiB/5.82 KiB
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# click                ------------------------------ 46.88 KiB/99.82 KiB
# ⠙ Preparing packages... (0/7)
# pastel               ------------------------------ 5.82 KiB/5.82 KiB
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# click                ------------------------------ 62.88 KiB/99.82 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 14.88 KiB/76.70 KiB
# poethepoet           ------------------------------ 16.00 KiB/83.84 KiB
# click                ------------------------------ 78.88 KiB/99.82 KiB
# pyyaml               ------------------------------ 16.00 KiB/745.07 KiB
# numpy                ------------------------------ 14.88 KiB/16.04 MiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 46.88 KiB/76.70 KiB
# poethepoet           ------------------------------ 16.00 KiB/83.84 KiB
# pyyaml               ------------------------------ 32.00 KiB/745.07 KiB
# numpy                ------------------------------ 14.88 KiB/16.04 MiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------
MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 4.75 MiB/16.04 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 4.75 MiB/16.04 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 4.75 MiB/16.04 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 4.75 MiB/16.04 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 4.75 MiB/16.04 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 4.75 MiB/16.04 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 4.75 MiB/16.04 MiB
# ⠼ Preparing packages... (5/7)
# numpy                ------------------------------ 4.75 MiB/16.04 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 4.75 MiB/16.04 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 4.76 MiB/16.04 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 4.77 MiB/16.04 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 4.78 MiB/16.04 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 4.79 MiB/16.04 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 4.80 MiB/16.04 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 4.81 MiB/16.04 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 4.82 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠧ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠇ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠋ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠙ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠹ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠼ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠧ Preparing packages... (5/7)
# numpy                ------------------------------ 6.17 MiB/16.04 MiB
# ⠧ Preparing packages... (5/7)
# numpy                ------------------------------ 6.22 MiB/16.04 MiB
# ⠧ Preparing packages... (5/7)
# numpy                ------------------------------ 6.23 MiB/16.04 MiB
# ⠧ Preparing packages... (5/7)
# numpy                ------------------------------ 6.42 MiB/16.04 MiB
# ⠧ Preparing packages... (5/7)
# numpy                ------------------------------ 6.42 MiB/16.04 MiB
# ⠧ Preparing packages... (5/7)
# numpy                ------------------------------ 6.53 MiB/16.04 MiB
# ⠇ Preparing packages... (5/7)
# numpy                ------------------------------ 6.53 MiB/16.04 MiB
# ⠇ Preparing packages... (5/7)
# numpy                ------------------------------ 6.56 MiB/16.04 MiB
# ⠇ Preparing packages... (5/7)
# numpy                ------------------------------ 6.58 MiB/16.04 MiB
# ⠇ Preparing packages... (5/7)
# numpy                ------------------------------ 6.59 MiB/16.04 MiB
# ⠋ Preparing packages... (5/7)
# numpy                ------------------------------ 6.62 MiB/16.04 MiB
# ⠋ Preparing packages... (5/7)
# numpy                ------------------------------ 6.64 MiB/16.04 MiB
# ⠋ Preparing packages... (5/7)
# numpy                ------------------------------ 6.73 MiB/16.04 MiB
# ⠋ Preparing packages... (5/7)
# numpy                ------------------------------ 6.75 MiB/16.04 MiB
# ⠙ Preparing packages... (5/7)
# numpy                ------------------------------ 6.80 MiB/16.04 MiB
# ⠙ Preparing packages... (5/7)
# numpy                ------------------------------ 6.89 MiB/16.04 MiB
# ⠙ Preparing packages... (5/7)
# numpy                ------------------------------ 7.47 MiB/16.04 MiB
# ⠙ Preparing packages... (5/7)
# numpy                ------------------------------ 7.68 MiB/16.04 MiB
# ⠹ Preparing packages... (5/7)
# numpy                ------------------------------ 8.34 MiB/16.04 MiB
# ⠹ Preparing packages... (5/7)
# numpy                ------------------------------ 9.81 MiB/16.04 MiB
# ⠹ Preparing packages... (5/7)
# numpy                ------------------------------ 10.03 MiB/16.04 MiB
# ⠹ Preparing packages... (5/7)
# numpy                ------------------------------ 11.68 MiB/16.04 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 11.68 MiB/16.04 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 13.17 MiB/16.04 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 13.69 MiB/16.04 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 13.69 MiB/16.04 MiB
# ⠼ Preparing packages... (5/7)
# numpy                ------------------------------ 15.36 MiB/16.04 MiB
# ⠼ Preparing packages... (5/7)
# numpy                ------------------------------ 15.58 MiB/16.04 MiB
# ⠼ Preparing packages... (5/7)
# numpy                ------------------------------ 15.83 MiB/16.04 MiB
# ⠼ Preparing packages... (5/7)
# numpy                ------------------------------ 15.97 MiB/16.04 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 15.98 MiB/16.04 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 16.02 MiB/16.04 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 16.03 MiB/16.04 MiB
# ⠴ Preparing packages... (5/7)
# ⠴ Preparing packages... (5/7)
# ⠦ Preparing packages... (5/7)
# ⠦ Preparing packages... (5/7)
# ⠦ Preparing packages... (5/7)
# ⠦ Preparing packages... (5/7)
# ⠧ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠦ Preparing packages... (6/7)
# ⠦ Preparing packages... (6/7)
# ⠦ Preparing packages... (6/7)
# ⠦ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# Installed 7 packages in 37ms
# Poe => mojo problems/p02/p02.mojo
# out: HostBuffer([0.0, 2.0, 4.0, 6.0])
# expected: HostBuffer([0.0, 2.0, 4.0, 6.0])
