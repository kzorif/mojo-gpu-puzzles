# %%
# !pip install max --index-url https://dl.modular.com/public/nightly/python/simple/
# Out:
# Looking in indexes: https://dl.modular.com/public/nightly/python/simple/
# Collecting max
#   Downloading https://dl.modular.com/public/nightly/python/max-25.4.0.dev2025060805-py3-none-manylinux_2_34_x86_64.whl (285.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.2/285.2 MB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from max) (8.2.1)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.11/dist-packages (from max) (2.0.2)
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.11/dist-packages (from max) (4.67.1)
# Installing collected packages: max
# Successfully installed max-25.4.0.dev2025060805

# %%
# !git clone https://github.com/modular/mojo-gpu-puzzles
# Out:
# Cloning into 'mojo-gpu-puzzles'...
# remote: Enumerating objects: 4059, done.
# remote: Counting objects: 100% (166/166), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 4059 (delta 151), reused 127 (delta 127), pack-reused 3893 (from 2)
# Receiving objects: 100% (4059/4059), 94.69 MiB | 16.13 MiB/s, done.
# Resolving deltas: 100% (2489/2489), done.

# %%
# !curl -fsSL https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.7.12 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
import max.support.notebook

# %%
def save_code_to_file(text: str, filename: str):
    with open(filename, 'w', encoding='utf-8') as file:
        file.write(text)

# %%
mojo_code = """
from memory import UnsafePointer
from gpu import thread_idx, block_dim, block_idx
from gpu.host import DeviceContext, HostBuffer
from testing import assert_equal

# ANCHOR: broadcast_add
alias SIZE = 2
alias BLOCKS_PER_GRID = 1
alias THREADS_PER_BLOCK = (3, 3)
alias dtype = DType.float32


fn broadcast_add(
    output: UnsafePointer[Scalar[dtype]],
    a: UnsafePointer[Scalar[dtype]],
    b: UnsafePointer[Scalar[dtype]],
    size: Int,
):
    row = thread_idx.y
    col = thread_idx.x
    # FILL ME IN (roughly 2 lines)
    if row < size and col < size:
      output[row*size+col] = a[col] + b[row]


# ANCHOR_END: broadcast_add
def main():
    with DeviceContext() as ctx:
        out = ctx.enqueue_create_buffer[dtype](SIZE * SIZE).enqueue_fill(0)
        expected = ctx.enqueue_create_host_buffer[dtype](
            SIZE * SIZE
        ).enqueue_fill(0)
        a = ctx.enqueue_create_buffer[dtype](SIZE).enqueue_fill(0)
        b = ctx.enqueue_create_buffer[dtype](SIZE).enqueue_fill(0)
        with a.map_to_host() as a_host, b.map_to_host() as b_host:
            for i in range(SIZE):
                a_host[i] = i
                b_host[i] = i

            for i in range(SIZE):
                for j in range(SIZE):
                    expected[i * SIZE + j] = a_host[i] + b_host[j]

        ctx.enqueue_function[broadcast_add](
            out.unsafe_ptr(),
            a.unsafe_ptr(),
            b.unsafe_ptr(),
            SIZE,
            grid_dim=BLOCKS_PER_GRID,
            block_dim=THREADS_PER_BLOCK,
        )

        ctx.synchronize()

        with out.map_to_host() as out_host:
            print("out:", out_host)
            print("expected:", expected)
            for i in range(SIZE):
                for j in range(SIZE):
                    assert_equal(out_host[i * SIZE + j], expected[i * SIZE + j])


"""

# %%
save_code_to_file(mojo_code, "/content/mojo-gpu-puzzles/problems/p05/p05.mojo")

# %%
# !cd /content/mojo-gpu-puzzles && uv run poe p05
# Out:
# Using CPython 3.11.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# ⠙ Preparing packages... (0/7)
# ⠙ Preparing packages... (0/7)
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------     0 B/76.70 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------     0 B/76.70 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------     0 B/76.70 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------     0 B/76.70 KiB
# click                ------------------------------     0 B/99.82 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 16.00 KiB/76.70 KiB
# click                ------------------------------     0 B/99.82 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 16.00 KiB/76.70 KiB
# click                ------------------------------ 14.88 KiB/99.82 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 16.00 KiB/76.70 KiB
# click                ------------------------------ 30.88 KiB/99.82 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 16.00 KiB/76.70 KiB
# click                ------------------------------ 46.88 KiB/99.82 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 16.00 KiB/76.70 KiB
# click                ------------------------------ 62.88 KiB/99.82 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 16.00 KiB/76.70 KiB
# click                ------------------------------ 62.88 KiB/99.82 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 16.00 KiB/76.70 KiB
# click                ------------------------------ 62.88 KiB/99.82 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 16.00 KiB/76.70 KiB
# click                ------------------------------ 62.88 KiB/99.82 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 16.00 KiB/76.70 KiB
# click                ------------------------------ 62.88 KiB/99.82 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 16.00 KiB/76.70 KiB
# click                ------------------------------ 62.88 KiB/99.82 KiB
# pyyaml               ------------------------------     0 B/745.07 KiB
# ⠙ Preparing packages... (0/7)
# tqdm                 ------------------------------ 16.00 KiB/76.70 KiB
# click                ------------------------------ 62.88 KiB/99.82 KiB
# pyyaml               ------------------------------ 16.00 KiB/745.07 KiB
# ⠙ Preparing packages... (0/7)
# pastel               ------------------------------ 5.82 KiB/5.82 KiB
# poethepoet           ------------------------------ 16.00 KiB/85.12 KiB
# click                ------------------------------ 62.88 KiB/99.82 KiB
# pyyaml               ------------------------------ 16.00 KiB/745.07 KiB
# ⠙ Preparing packages... (0/7)
# poethepoet           ------------------------------ 16.00 KiB/85.12 KiB
# click                ------------------------------ 78.88 KiB/99.82 KiB
# pyyaml               ------------------------------ 16.00 KiB/745.07 KiB
# ⠙ Preparing packages... (0/7)
# poethepoet           ------------------------------ 16.00 KiB/85.12 KiB
# pyyaml               ------------------------------ 16.00 KiB/745.07 KiB
# ⠙ Preparing packages... (0/7)
# poethepoet           ------------------------------ 80.00 KiB/85.12 KiB
# pyyaml               ------------------------------ 32.00 KiB/745.07 KiB
# numpy                ------------------------------ 157.52 KiB/16.15 MiB
# ⠙ Preparing packages... (0/7)
# poethepoet           ------------------------------ 80.00 KiB/85.12 KiB
# pyyaml               ------------------------------ 32.00 KiB/745.07 KiB
# numpy                ------------------------------ 1.92 MiB/16.15 MiB
# ⠙ Preparing packages... (0/7)
# pyyaml               ------------------------------ 32.00 KiB/745.07 KiB
# numpy                ------------------------------ 2.00 MiB/16.15 MiB
# ⠙ Preparing packages... (0/7)
# numpy                ------------------------------ 2.00 MiB/16.15 MiB
# ⠙ Preparing packages... (0/7)
# numpy                ------------------------------ 2.65 MiB/16.15 MiB
# ⠙ Preparing packages... (0/7)
# numpy                ------------------------------ 4.00 MiB/16.15 MiB
# ⠹ Preparing packages... (5/7)
# numpy                ------------------------------ 4.65 MiB/16.15 MiB
# ⠹ Preparing packages... (5/7)
# numpy                ------------------------------ 5.17 MiB/16.15 MiB
# ⠹ Preparing packages... (5/7)
# numpy                ------------------------------ 5.25 MiB/16.15 MiB
# ⠹ Preparing packages... (5/7)
# numpy                ------------------------------ 5.44 MiB/16.15 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 5.45 MiB/16.15 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 5.72 MiB/16.15 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 6.36 MiB/16.15 MiB
# ⠸ Preparing packages... (5/7)
# numpy                ------------------------------ 6.47 MiB/16.15 MiB
# ⠼ Preparing packages... (5/7)
# numpy                ------------------------------ 7.67 MiB/16.15 MiB
# ⠼ Preparing packages... (5/7)
# numpy                ------------------------------ 7.89 MiB/16.15 MiB
# ⠼ Preparing packages... (5/7)
# numpy                ------------------------------ 7.98 MiB/16.15 MiB
# ⠼ Preparing packages... (5/7)
# numpy                ------------------------------ 8.06 MiB/16.15 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 9.12 MiB/16.15 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 9.97 MiB/16.15 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 10.06 MiB/16.15 MiB
# ⠴ Preparing packages... (5/7)
# numpy                ------------------------------ 11.53 MiB/16.15 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 12.31 MiB/16.15 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 13.22 MiB/16.15 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 13.94 MiB/16.15 MiB
# ⠦ Preparing packages... (5/7)
# numpy                ------------------------------ 14.56 MiB/16.15 MiB
# ⠧ Preparing packages... (5/7)
# numpy                ------------------------------ 15.79 MiB/16.15 MiB
# ⠧ Preparing packages... (5/7)
# numpy                ------------------------------ 15.94 MiB/16.15 MiB
# ⠧ Preparing packages... (5/7)
# ⠧ Preparing packages... (5/7)
# ⠧ Preparing packages... (5/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠦ Preparing packages... (6/7)
# ⠦ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠦ Preparing packages... (6/7)
# ⠦ Preparing packages... (6/7)
# ⠦ Preparing packages... (6/7)
# ⠦ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠸ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠼ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠴ Preparing packages... (6/7)
# ⠦ Preparing packages... (6/7)
# ⠦ Preparing packages... (6/7)
# ⠦ Preparing packages... (6/7)
# ⠦ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠧ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠇ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠋ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠙ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# ⠹ Preparing packages... (6/7)
# Installed 7 packages in 32ms
# Poe => mojo problems/p05/p05.mojo
# out: HostBuffer([0.0, 1.0, 1.0, 2.0])
# expected: HostBuffer([0.0, 1.0, 1.0, 2.0])
